# %%
# !git config --global user.email 1833928261@qq.com
# !git config --global user.name dyf2316
# Out:
# /content/drive/MyDrive/nlp_project/nlp_text_summarization

# %%
# %cd /content/drive/MyDrive/nlp_project/nlp_text_summarization1/
# Out:
# /content/drive/MyDrive/nlp_project/nlp_text_summarization1

# %%
# %cd /content/drive/MyDrive/nlp_project/nlp_text_summarization/

# %%
# !git status
# Out:
# On branch dyf
# Your branch is up to date with 'origin/dyf'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m '中文适配rouge计算'
# Out:
# [dyf d452324] 中文适配rouge计算
#  10 files changed, 31 insertions(+), 21 deletions(-)
#  mode change 100755 => 100644 Global-Encoding-master/RELEASE-1.5.5/ROUGE-1.5.5.pl
#  mode change 100755 => 100644 Global-Encoding-master/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/buildExeptionDB.pl
#  mode change 100755 => 100644 Global-Encoding-master/RELEASE-1.5.5/runROUGE-test.pl
#  delete mode 100644 requirements.txt

# %%
# !git push
# Out:
# Counting objects: 13, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 2.85 KiB | 1.42 MiB/s, done.
# Total 13 (delta 11), reused 0 (delta 0)
# remote: Powered by GITEE.COM [GNK-6.3]
# To https://gitee.com/dyf2316/nlp_text_summarization.git
#    0a949e7..d452324  dyf -> dyf

# %%
# !git pull

# %% [markdown]
# # GEM

# %% [markdown]
# ## python环境

# %%
# !apt-get install python3.5

# %%
# !wget https://repo.anaconda.com/archive/Anaconda3-5.2.0-Linux-x86_64.sh

# %%
# !bash Anaconda3-5.2.0-Linux-x86_64.sh -bfp /usr/local

# %%
import sys
sys.path.insert(0, "/usr/local/lib/python3.7/site-packages/")

# %% [markdown]
# ## rouge包

# %%
# !sudo apt install cpanminus

# %%
# !sudo cpan XML::DOM
# !sudo cpan XML::Parser
# !sudo cpan XML::RegExp
# !sudo cpan XML::Parser::PerlSAX

# %%
# %cd /content/drive/MyDrive/nlp_project/ROUGE

# %%
# !git clone https://github.com/summanlp/evaluation

# %%
# !export ROUGE_EVAL_HOME="/content/drive/MyDrive/nlp_project/ROUGE/evaluation/ROUGE-RELEASE-1.5.5"

# %%
# !pip install pyrouge
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 60 kB 6.0 MB/s
# ...
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191621 sha256=8c4d669b83d6cd67a1a5a72be3ea0fbf3a2f3fb9d357ff6e4ad0663c7bb0646e
#   Stored in directory: /root/.cache/pip/wheels/68/35/6a/ffb9a1f51b2b00fee42e7f67f5a5d8e10c67d048cda09ccd57
# Successfully built pyrouge
# ...

# %%
# !pyrouge_set_rouge_path /content/drive/MyDrive/nlp_project/ROUGE/evaluation/ROUGE-RELEASE-1.5.5
# Out:
# 2022-05-28 11:06:19,581 [MainThread  ] [INFO ]  Set ROUGE home directory to /content/drive/MyDrive/nlp_project/ROUGE/evaluation/ROUGE-RELEASE-1.5.5.

# %% [markdown]
# ## 分词

# %%
# %cd /content/drive/MyDrive/nlp_project/nlp_text_summarization
# !python chinese_tokenize.py
# Out:
# /content/drive/MyDrive/nlp_project/nlp_text_summarization
# ./mini_lcsts
# []
# ['valid.tgt', 'train.tgt', 'test.tgt', 'valid.src', 'test.src', 'train.src']
# ./mini_lcsts/valid.tgt
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.750 seconds.
# Prefix dict has been built successfully.
# ./mini_lcsts/train.tgt
# ./mini_lcsts/test.tgt
# ./mini_lcsts/valid.src
# ./mini_lcsts/test.src
# ./mini_lcsts/train.src

# %% [markdown]
# ## 模型

# %%
# %cd /content/drive/MyDrive/nlp_project/nlp_text_summarization/Global-Encoding
# Out:
# /content/drive/MyDrive/nlp_project/nlp_text_summarization/Global-Encoding

# %%
# !python preprocess.py -load_data ../prep_data/ -save_data ./data/
# Out:
# Building source vocabulary...
# ../prep_data/train.src: length limit = 0, truncate length = 0
# Max length of ../prep_data/train.src = 99
# Created dictionary of size 50004 (pruned from 279181)
# Building target vocabulary...
# ../prep_data/train.tgt: length limit = 0, truncate length = 0
# Max length of ../prep_data/train.tgt = 25
# Created dictionary of size 50004 (pruned from 125403)
# Preparing training ...
# Processing ../prep_data/train.src & ../prep_data/train.tgt ...
# ... 100000 sentences prepared
# ... 200000 sentences prepared
# Prepared 200000 sentences (0 and 0 ignored due to length == 0 or > )
# Preparing validation ...
# Processing ../prep_data/valid.src & ../prep_data/valid.tgt ...
# Prepared 1000 sentences (0 and 0 ignored due to length == 0 or > )
# Preparing test ...
# Processing ../prep_data/test.src & ../prep_data/test.tgt ...
# Prepared 1000 sentences (0 and 0 ignored due to length == 0 or > )
# Saving source vocabulary to './data/src.dict'...
# ...

# %%
# !chmod 777 /content/drive/MyDrive/nlp_project/ROUGE/evaluation/ROUGE-RELEASE-1.5.5/ROUGE-1.5.5.pl

# %%
# !python train.py -config lcsts.yaml -gpus 0
